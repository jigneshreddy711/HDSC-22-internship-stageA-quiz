# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("FoodBalanceSheets.csv", encoding='gbk')

# %%
df.head()
# df.info()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df['Y2015'].describe()
# Out:
# count     59395.000000
# mean        135.235966
# std        1603.403984
# min       -3161.000000
# 25%           0.000000
# 50%           0.080000
# 75%           8.460000
# max      181137.000000
# Name: Y2015, dtype: float64

# %%
len(df.Area.unique())
# Out:
# 49

# %%
import_quantity = pd.DataFrame(df.groupby(['Element', 'Area'])['Y2018'].sum())
import_quantity.loc['Import Quantity']
# Out:
#                                 Y2018
# Area
# Algeria                      36238.29
# Angola                        7769.67
# Benin                         7008.24
# Botswana                      1908.42
# Burkina Faso                  2605.64
# Cabo Verde                     499.66
# Cameroon                      4188.88
# Central African Republic        75.02
# Chad                           491.95
# Comoros                          2.92
# Congo                         1785.27
# C魌e d'Ivoire                  9271.21
# Djibouti                      3784.92
# Egypt                        53954.20
# Eswatini                       936.53
# Ethiopia                      5655.24
# Ethiopia PDR                     0.00
# Gabon                         1079.75
# Gambia                        1212.10
# Ghana                         9914.68
# Guinea                        4707.95
# Guinea-Bissau                  497.72
# Kenya                        11188.96
# ...

# %%
df['Y2016'].isnull().sum()
# Out:
# 1535

# %%
df.corr()['Element Code']
# Out:
# Area Code      -0.000209
# Item Code      -0.024683
# Element Code    1.000000
# Y2014           0.024457
# Y2015           0.023889
# Y2016           0.023444
# Y2017           0.024254
# Y2018           0.024279
# Name: Element Code, dtype: float64

# %%
df.groupby(['Area'])['Y2018'].unique()
# Out:
# Area
# Algeria                        [42228.0, 0.0, 3322.0, 91.83, 77.28, 2932.0, 6...
# Angola                         [30810.0, 0.0, 2385.0, 53.05, 57.73, 2177.0, 3...
# Benin                          [11485.0, 0.0, 2755.0, 63.97, 51.96, 2635.0, 5...
# Botswana                       [2254.0, 0.0, 2342.0, 65.89, 65.37, 1944.0, 37...
# Burkina Faso                   [19751.0, 0.0, 2737.0, 80.16, 66.09, 2578.0, 6...
# Cabo Verde                     [544.0, 0.0, 2541.0, 70.86, 66.08, 2120.0, 44....
# Cameroon                       [25216.0, 0.0, 2733.0, 71.89, 54.39, 2615.0, 6...
# Central African Republic       [4666.0, 0.0, 1786.0, 44.58, 60.73, 1534.0, 24...
# Chad                           [15478.0, 0.0, 2115.0, 61.51, 52.87, 1990.0, 5...
# Comoros                        [0.0, 0.04, 0.8, 0.02, 0.82, 14.14, 2.51, 16.6...
# Congo                          [5244.0, 0.0, 2285.0, 58.16, 45.56, 2069.0, 31...
# ...
